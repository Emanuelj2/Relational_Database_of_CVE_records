# %% [markdown]
# ### Import the library's needed

# %%
import numpy

from matplotlib import pyplot as plt
import pandas as pd
from tabulate import tabulate
import matplotlib.cm as cm

# %%
file_path = "Products.csv"
file_path2 = "CVE_RECORDS2.csv"

product_table = pd.read_csv(file_path)
cve_records_table = pd.read_csv(file_path2)

# %% [markdown]
# ### Print out both tables to see what you are working with

# %%
print(product_table.head())
print(cve_records_table.head())
# Out:
#    ID   NAME  CVSS_VERSION RDBMS_VERSION
# 0   1  MySQL           3.1         8.4.0
# 1   2  MySQL           3.1         8.3.0
# 2   3  MySQL           3.1        8.0.34
# 3   4  MySQL           3.1        8.0.30
# 4   5  MySQL           3.1        5.1.48
#    ID  CVSS_SCORE                                             LINK  \
# 0   1         2.2  https://nvd.nist.gov/vuln/detail/CVE-2024-21232
# 1   2         4.9  https://nvd.nist.gov/vuln/detail/CVE-2024-21102
# 2   3         4.9  https://nvd.nist.gov/vuln/detail/CVE-2023-22078
# 3   4         2.7  https://nvd.nist.gov/vuln/detail/CVE-2023-21874
# 4   5         2.2   https://nvd.nist.gov/vuln/detail/CVE-2020-2933
#
#   PUBLISHED_DATE LAST_MODIFIED
# 0     2024-10-15    2024-10-16
# 1     2024-04-16    2024-04-26
# 2     2023-10-17    2023-12-22
# 3     2023-01-17    2023-01-24
# 4     2020-04-15    2023-11-06

# %% [markdown]
# # join both the tables

# %%
merge_data = pd.merge(product_table, cve_records_table, on='ID')

# %%
merge_data.head(25)
# Out:
#     ID         NAME  CVSS_VERSION RDBMS_VERSION  CVSS_SCORE  \
# 0    1        MySQL           3.1         8.4.0         2.2
# 1    2        MySQL           3.1         8.3.0         4.9
# 2    3        MySQL           3.1        8.0.34         4.9
# 3    4        MySQL           3.1        8.0.30         2.7
# 4    5        MySQL           3.1        5.1.48         2.2
# 5    6   PostgreSQL           2.0        8.3.18         6.8
# 6    7   PostgreSQL           3.1            12         8.8
# 7    8   PostgreSQL           2.0         9.3.3         4.6
# 8    9   PostgreSQL           2.0         7.2.1         5.0
# 9   10   PostgreSQL           2.0         6.5.0         7.5
# 10  11  MSSQLSERVER           3.1            15         7.8
# 11  12  MSSQLSERVER           2.0             7         9.0
# 12  13  MSSQLSERVER           2.0            11         7.5
# 13  14  MSSQLSERVER           2.0             5         5.0
# 14  15  MSSQLSERVER           2.0           6.5         7.2
# 15  16     OracleDB           3.1          23.4         3.1
# 16  17     OracleDB           3.1          20.1         2.6
# 17  18     OracleDB           3.1      12.2.0.1         3.1
# 18  19     OracleDB           3.1           5.1         4.6
# 19  20     OracleDB           3.0      11.2.0.4         2.3
# 20  21      MariaDB           3.1        15.5.0         5.4
# 21  22      MariaDB           3.1       23.02.3         6.5
# 22  23      MariaDB           3.1        10.9.3         6.5
# 23  24      MariaDB           3.1        10.9.2         5.5
# 24  25      MariaDB           3.1          10.5         7.5
#
#                                                LINK PUBLISHED_DATE  \
# 0   https://nvd.nist.gov/vuln/detail/CVE-2024-21232     2024-10-15
# 1   https://nvd.nist.gov/vuln/detail/CVE-2024-21102     2024-04-16
# 2   https://nvd.nist.gov/vuln/detail/CVE-2023-22078     2023-10-17
# 3   https://nvd.nist.gov/vuln/detail/CVE-2023-21874     2023-01-17
# 4    https://nvd.nist.gov/vuln/detail/CVE-2020-2933     2020-04-15
# 5    https://nvd.nist.gov/vuln/detail/CVE-2012-0868     2012-07-18
# 6    https://nvd.nist.gov/vuln/detail/CVE-2024-7348     2024-08-08
# 7    https://nvd.nist.gov/vuln/detail/CVE-2014-0067     2014-03-31
# 8    https://nvd.nist.gov/vuln/detail/CVE-2004-0547     2004-08-06
# 9    https://nvd.nist.gov/vuln/detail/CVE-2002-0802     2002-08-12
# 10  https://nvd.nist.gov/vuln/detail/CVE-2024-49021     2024-11-12
# 11   https://nvd.nist.gov/vuln/detail/CVE-2008-0107     2008-07-08
# 12   https://nvd.nist.gov/vuln/detail/CVE-2005-1272     2005-08-05
# 13   https://nvd.nist.gov/vuln/detail/CVE-2002-0224     2002-05-16
# 14   https://nvd.nist.gov/vuln/detail/CVE-1999-1556     1998-06-29
# 15  https://nvd.nist.gov/vuln/detail/CVE-2024-21251     2024-10-15
# 16  https://nvd.nist.gov/vuln/detail/CVE-2024-20911     2024-02-16
# 17  https://nvd.nist.gov/vuln/detail/CVE-2020-14743     2020-10-21
# 18   https://nvd.nist.gov/vuln/detail/CVE-2020-2977     2020-07-15
# 19  https://nvd.nist.gov/vuln/detail/CVE-2017-10292     2017-10-19
# 20  https://nvd.nist.gov/vuln/detail/CVE-2024-24812     2024-02-07
# 21  https://nvd.nist.gov/vuln/detail/CVE-2023-40354     2023-08-14
# 22  https://nvd.nist.gov/vuln/detail/CVE-2022-47015     2023-01-20
# 23  https://nvd.nist.gov/vuln/detail/CVE-2022-38791     2022-08-27
# 24  https://nvd.nist.gov/vuln/detail/CVE-2022-32089     2022-07-01
#
#    LAST_MODIFIED
# 0     2024-10-16
# 1     2024-04-26
# 2     2023-12-22
# 3     2023-01-24
# 4     2023-11-06
# 5     2016-12-07
# 6     2024-08-12
# 7     2017-12-15
# 8     2017-07-10
# 9     2016-10-17
# 10    2024-11-13
# 11    2019-02-26
# 12    2021-04-07
# 13    2019-04-30
# 14    2017-10-09
# 15    2024-10-31
# 16    2024-02-20
# 17    2020-10-22
# 18    2024-07-20
# 19    2019-10-02
# 20    2024-02-14
# 21    2023-08-22
# 22    2024-06-06
# 23    2023-11-06
# 24    2023-11-06

# %%
group_by_name = merge_data.groupby('NAME')
for name, group in group_by_name:
    print(f'Group {name}')
    print(tabulate(group, headers='keys', tablefmt='pretty'))
# Out:
# Group MSSQLSERVER
# +----+----+-------------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# |    | ID |    NAME     | CVSS_VERSION | RDBMS_VERSION | CVSS_SCORE |                      LINK                       | PUBLISHED_DATE | LAST_MODIFIED |
# +----+----+-------------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# | 10 | 11 | MSSQLSERVER |     3.1      |      15       |    7.8     | https://nvd.nist.gov/vuln/detail/CVE-2024-49021 |   2024-11-12   |  2024-11-13   |
# | 11 | 12 | MSSQLSERVER |     2.0      |       7       |    9.0     | https://nvd.nist.gov/vuln/detail/CVE-2008-0107  |   2008-07-08   |  2019-02-26   |
# | 12 | 13 | MSSQLSERVER |     2.0      |      11       |    7.5     | https://nvd.nist.gov/vuln/detail/CVE-2005-1272  |   2005-08-05   |  2021-04-07   |
# | 13 | 14 | MSSQLSERVER |     2.0      |       5       |    5.0     | https://nvd.nist.gov/vuln/detail/CVE-2002-0224  |   2002-05-16   |  2019-04-30   |
# | 14 | 15 | MSSQLSERVER |     2.0      |      6.5      |    7.2     | https://nvd.nist.gov/vuln/detail/CVE-1999-1556  |   1998-06-29   |  2017-10-09   |
# +----+----+-------------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# Group MariaDB
# +----+----+---------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# |    | ID |  NAME   | CVSS_VERSION | RDBMS_VERSION | CVSS_SCORE |                      LINK                       | PUBLISHED_DATE | LAST_MODIFIED |
# +----+----+---------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# | 20 | 21 | MariaDB |     3.1      |    15.5.0     |    5.4     | https://nvd.nist.gov/vuln/detail/CVE-2024-24812 |   2024-02-07   |  2024-02-14   |
# | 21 | 22 | MariaDB |     3.1      |    23.02.3    |    6.5     | https://nvd.nist.gov/vuln/detail/CVE-2023-40354 |   2023-08-14   |  2023-08-22   |
# | 22 | 23 | MariaDB |     3.1      |    10.9.3     |    6.5     | https://nvd.nist.gov/vuln/detail/CVE-2022-47015 |   2023-01-20   |  2024-06-06   |
# | 23 | 24 | MariaDB |     3.1      |    10.9.2     |    5.5     | https://nvd.nist.gov/vuln/detail/CVE-2022-38791 |   2022-08-27   |  2023-11-06   |
# | 24 | 25 | MariaDB |     3.1      |     10.5      |    7.5     | https://nvd.nist.gov/vuln/detail/CVE-2022-32089 |   2022-07-01   |  2023-11-06   |
# +----+----+---------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# Group MySQL
# +---+----+-------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# |   | ID | NAME  | CVSS_VERSION | RDBMS_VERSION | CVSS_SCORE |                      LINK                       | PUBLISHED_DATE | LAST_MODIFIED |
# +---+----+-------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# | 0 | 1  | MySQL |     3.1      |     8.4.0     |    2.2     | https://nvd.nist.gov/vuln/detail/CVE-2024-21232 |   2024-10-15   |  2024-10-16   |
# | 1 | 2  | MySQL |     3.1      |     8.3.0     |    4.9     | https://nvd.nist.gov/vuln/detail/CVE-2024-21102 |   2024-04-16   |  2024-04-26   |
# | 2 | 3  | MySQL |     3.1      |    8.0.34     |    4.9     | https://nvd.nist.gov/vuln/detail/CVE-2023-22078 |   2023-10-17   |  2023-12-22   |
# | 3 | 4  | MySQL |     3.1      |    8.0.30     |    2.7     | https://nvd.nist.gov/vuln/detail/CVE-2023-21874 |   2023-01-17   |  2023-01-24   |
# | 4 | 5  | MySQL |     3.1      |    5.1.48     |    2.2     | https://nvd.nist.gov/vuln/detail/CVE-2020-2933  |   2020-04-15   |  2023-11-06   |
# +---+----+-------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# Group OracleDB
# +----+----+----------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# |    | ID |   NAME   | CVSS_VERSION | RDBMS_VERSION | CVSS_SCORE |                      LINK                       | PUBLISHED_DATE | LAST_MODIFIED |
# +----+----+----------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# | 15 | 16 | OracleDB |     3.1      |     23.4      |    3.1     | https://nvd.nist.gov/vuln/detail/CVE-2024-21251 |   2024-10-15   |  2024-10-31   |
# | 16 | 17 | OracleDB |     3.1      |     20.1      |    2.6     | https://nvd.nist.gov/vuln/detail/CVE-2024-20911 |   2024-02-16   |  2024-02-20   |
# | 17 | 18 | OracleDB |     3.1      |   12.2.0.1    |    3.1     | https://nvd.nist.gov/vuln/detail/CVE-2020-14743 |   2020-10-21   |  2020-10-22   |
# | 18 | 19 | OracleDB |     3.1      |      5.1      |    4.6     | https://nvd.nist.gov/vuln/detail/CVE-2020-2977  |   2020-07-15   |  2024-07-20   |
# | 19 | 20 | OracleDB |     3.0      |   11.2.0.4    |    2.3     | https://nvd.nist.gov/vuln/detail/CVE-2017-10292 |   2017-10-19   |  2019-10-02   |
# +----+----+----------+--------------+---------------+------------+-------------------------------------------------+----------------+---------------+
# Group PostgreSQL
# +---+----+------------+--------------+---------------+------------+------------------------------------------------+----------------+---------------+
# |   | ID |    NAME    | CVSS_VERSION | RDBMS_VERSION | CVSS_SCORE |                      LINK                      | PUBLISHED_DATE | LAST_MODIFIED |
# +---+----+------------+--------------+---------------+------------+------------------------------------------------+----------------+---------------+
# | 5 | 6  | PostgreSQL |     2.0      |    8.3.18     |    6.8     | https://nvd.nist.gov/vuln/detail/CVE-2012-0868 |   2012-07-18   |  2016-12-07   |
# | 6 | 7  | PostgreSQL |     3.1      |      12       |    8.8     | https://nvd.nist.gov/vuln/detail/CVE-2024-7348 |   2024-08-08   |  2024-08-12   |
# | 7 | 8  | PostgreSQL |     2.0      |     9.3.3     |    4.6     | https://nvd.nist.gov/vuln/detail/CVE-2014-0067 |   2014-03-31   |  2017-12-15   |
# | 8 | 9  | PostgreSQL |     2.0      |     7.2.1     |    5.0     | https://nvd.nist.gov/vuln/detail/CVE-2004-0547 |   2004-08-06   |  2017-07-10   |
# | 9 | 10 | PostgreSQL |     2.0      |     6.5.0     |    7.5     | https://nvd.nist.gov/vuln/detail/CVE-2002-0802 |   2002-08-12   |  2016-10-17   |
# +---+----+------------+--------------+---------------+------------+------------------------------------------------+----------------+---------------+

# %%
for name, group in group_by_name:
    plt.figure(figsize=(8, 6))
    
    # Plot histogram for the current group and retrieve the data
    counts, bins, patches = plt.hist(group['CVSS_SCORE'], bins=10, alpha=0.7, edgecolor='black', label=name)
    
    # Apply a colormap to the bars
    cmap = plt.get_cmap('plasma')  # You can choose any colormap
    norm = plt.Normalize(vmin=0, vmax=max(counts))  # Normalize counts for consistent color mapping
    for count, patch in zip(counts, patches):
        color = cmap(norm(count))  # Get color based on count
        patch.set_facecolor(color)
    
    # Add title and labels
    plt.title(f'Histogram of CVSS Scores for Group: {name}')
    plt.xlabel('CVSS Score')
    plt.ylabel('Frequency')
    
    # Add grid for better readability
    plt.grid(axis='y', alpha=0.75)
    
    # Add legend
    plt.legend(loc='upper right')
    
    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(12, 8))  # Increase figure size for more space

# Create a colormap and set up normalization
cmap = plt.get_cmap('viridis')  # Replace 'viridis' with any colormap name
norm = plt.Normalize(vmin=0, vmax=1)  # Normalize the colormap to match the range of scores

# Loop over each group and plot its histogram on the same axes
for name, group in group_by_name:
    # Plot histogram for the current group
    counts, bins, patches = plt.hist(group['CVSS_SCORE'], bins=10, alpha=0.5, edgecolor='black', label=name)
    
    # Calculate the average CVSS_SCORE for the group
    avg_score = group['CVSS_SCORE'].mean()
    
    # Apply a color to the bars based on the colormap
    for count, patch in zip(counts, patches):
        color = cmap(norm(count / max(counts)))  # Normalize each count for colormap
        patch.set_facecolor(color)
    
    # Add average score annotation
    plt.text(0.95, avg_score, f'{name}: Avg={avg_score:.2f}', ha='right', va='center', fontsize=10, color='black', weight='bold')

# Set the title, labels, and grid
plt.title('Combined Histogram of CVSS Scores for All Groups')
plt.xlabel('CVSS Score')
plt.ylabel('Frequency')

# Add grid for better readability
plt.grid(axis='y', alpha=0.75)

# Add legend to differentiate groups (adjust position with bbox_to_anchor)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Adjust the layout to ensure everything fits
plt.subplots_adjust(right=0.85)  # Allow more space for the legend and annotations

# Display the plot
plt.show()

# %%
# !jupyter nbconvert --to script analyze_data.ipynb
# Out:
# [NbConvertApp] Converting notebook analyze_data.ipynb to script
# [NbConvertApp] ERROR | Notebook JSON is invalid: 'execution_count' is a required property
#
# Failed validating 'required' in code_cell:
#
# On instance['cells'][11]:
# {'cell_type': 'code',
#  'id': '44f078d03d5f32da',
#  'metadata': {'collapsed': False, 'is_executing': True},
#  'outputs': ['...0 outputs...'],
#  'source': '!jupyter nbconvert --to script analyze_data.ipynb'}
# [NbConvertApp] ERROR | Notebook is invalid after preprocessor <nbconvert.preprocessors.tagremove.TagRemovePreprocessor object at 0x10529da00>
# Traceback (most recent call last):
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/jupyter_core/application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/templateexporter.py", line 386, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/templateexporter.py", line 392, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore[return-value]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/script.py", line 63, in from_notebook_node
#     return exporter.from_notebook_node(nb, resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/templateexporter.py", line 408, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/exporter.py", line 355, in _preprocess
#     self._validate_preprocessor(nbc, preprocessor)
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbconvert/exporters/exporter.py", line 322, in _validate_preprocessor
#     nbformat.validate(nbc, relax_add_props=True)
#   File "/Users/emanueljose/Library/CloudStorage/OneDrive-Personal/DataBase2/.venv/lib/python3.12/site-packages/nbformat/validator.py", line 509, in validate
#     raise error
# nbformat.validator.NotebookValidationError: 'execution_count' is a required property
#
# Failed validating 'required' in code_cell:
#
# On instance['cells'][11]:
# {'cell_type': 'code',
#  'id': '44f078d03d5f32da',
#  'metadata': {'collapsed': False, 'is_executing': True},
#  'outputs': ['...0 outputs...'],
#  'source': '!jupyter nbconvert --to script analyze_data.ipynb'}
